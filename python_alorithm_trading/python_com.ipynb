# %% [markdown]
# # 파이썬 - 시스템 트레이딩

# %% [markdown]
# - https://www.youtube.com/watch?v=ED04jGkp4Sg

# %% [markdown]
# 1. 데이터 확보 : web data extraction, mysql db
# 2. 전략 : numpy, statsmodel, matplot
# 3. 이행 : api, excel lib, flask

# %% [markdown]
# #### 개인투자자 문제점
# 1. 비이성적인 대처
# 2. 정보량 부족
# 3. 불확실한 정보
# 4. 지속성 없음

# %% [markdown]
# 1. 데이터 탐색
#   - 국내 영업일, 해외 영업일(종목일별 데이터), 종목코드(financipe), 종목이름, 업종(finance.naver), 종가, 시가, 고가, 저가, 수익률(finance.naver), 거래량

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 금융데이터 속성의 이해
# - 거래비용 이해

# %%
import win64com.client
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-a987f43113c9> in <module>()
# ----> 1 import win64com.client
#
# ModuleNotFoundError: No module named 'win64com'
