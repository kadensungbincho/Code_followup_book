# %% [markdown]
# # Ch1. What Is a DBA?

# %% [markdown]
# Every organization using a database management system (DBMS) to manage data requires a database administration group to ensure the effective use and deployment of the company's databases. Since most modern orgatizations of any size use a DBMS, the need for a database administrator (DBA) is greater today than ever before. However, the discipline of database admiistration is neither well unserstood nor universally practiced in a coherent and easily replicated manner.

# %% [markdown]
# What is a DBA? The short answer is simple: A DBA is the information technician responsible for ensuring the ongoing operational functionality and efficiency of an organization's databases and the applications that access those databases.

# %% [markdown]
# ... Why spend so much time talking about data administration in a book about database daministration? Well, very few organiations have implemented and staffed a DA role. The larger the organization is, the more likely that a DA function exists. However, when the DA role is undefined in an organization, the DBA must assume the mantle of data planner and modeler.

# %% [markdown]
# ### Database Administration

# %% [markdown]
# The first duty of the DBA is to understand te data models built by the DA and to communicate the model to the application developers and other appropriate technicians. The logical data model is the map the DBA will use to create physical databases. The DBA will transform the logical data model into an efficient physical database design.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## DBA Tasks

# %% [markdown]
# ### Database Desing

# %% [markdown]
# ### Performance Monitoring and Tuning

# %% [markdown]
# - workload, throughput, resources, optimization, and contention.

# %% [markdown]
# ### Availability

# %% [markdown]
# ### Database Security and Authorization

# %% [markdown]
# ### Backup and Recovery

# %% [markdown]
# - recover to current
# - point-in-time-recovery
# - transaction recovery

# %% [markdown]
# ### Data integrity

# %% [markdown]
# - enforce datetype
#   - referential constraints
#   - unique constraints
#   - check constraints
#
# - semantic integrity

# %% [markdown]
# ### DBMS Release Migration

# %% [markdown]
# ## Types of DBAs

# %% [markdown]
# - System DBA
# - Database Architect
# - Database Analyst
# - Data Modeler
# - Application DBA
# - Task-Oriented
# - DW Admin

# %% [markdown]
# ## DBA Reporting Structures

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## New Technology and the DBA

# %% [markdown]
# - database-coupled application logic, Internet-enabled e- business development, and handheld computing.

# %% [markdown]
# ## Procedural DBAs : Managin Database Logic

# %% [markdown]
# - Stored Procedures

# %% [markdown]
# - The procedural DBA is responsible for those database mangament activities that require procedural logic support. He ensures that stored procedures, trigges, and user-defined functions are effectively planned, implemented, shared and reused. The procedural DBA also takes primary responsibility for coding and testing all triggers.

# %% [markdown]
# # Ch2 : Creating the Database Environment
